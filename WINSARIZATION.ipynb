# %% [markdown]
# <a href="https://colab.research.google.com/github/the-star-boy/Local-repo/blob/main/WINSARIZATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
import seaborn as sns

# %%
sns.displot(df['Height'])

# %%
sns.boxplot(x=df['Height'])
# Out:
# <Axes: xlabel='Height'>

# %%
upper_limit= df['Height'].quantile(0.99)
lower_limit= df['Height'].quantile(0.01)

# %%
lower_limit
# Out:
# np.float64(58.13441158671655)

# %%
new_df=df[(df['Height']<=74.78) & (df['Height']>=58.13)]

# %%
sns.distplot(new_df['Height'])
# Out:
# /tmp/ipykernel_6301/1622920233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(x=new_df['Height'])
# Out:
# <Axes: xlabel='Height'>

# %% [markdown]
# # **CAPPING** /**WINSARIZATION**

# %%
df['Height']=np.where(
    df['Height']>=upper_limit,upper_limit,
    np.where(df['Height']<lower_limit,lower_limit,
    df['Height']))

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
sns.displot(df['Height'])
